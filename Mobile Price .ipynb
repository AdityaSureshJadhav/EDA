# %% [markdown]
# # Mobile Price

# %%
 import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:/Users/DD/Desktop/Mobile Prices.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.tail(3)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [3 rows x 21 columns]

# %%
 df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100 #Percentage of Missing Values in each column
# Out:
# battery_power    0.0
# blue             0.0
# clock_speed      0.0
# dual_sim         0.0
# fc               0.0
# four_g           0.0
# int_memory       0.0
# m_dep            0.0
# mobile_wt        0.0
# n_cores          0.0
# pc               0.0
# px_height        0.0
# px_width         0.0
# ram              0.0
# sc_h             0.0
# sc_w             0.0
# talk_time        0.0
# three_g          0.0
# touch_screen     0.0
# wifi             0.0
# price_range      0.0
# dtype: float64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.dropna()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.rename(columns={'blue': 'bluetooth'},inplace=True)# Change Column Names and Data

# %%
df
# Out:
#       battery_power  bluetooth  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842          0          2.2         0   1       0           7
# 1              1021          1          0.5         1   0       1          53
# 2               563          1          0.5         1   2       1          41
# 3               615          1          2.5         0   0       0          10
# 4              1821          1          1.2         0  13       1          44
# ...             ...        ...          ...       ...  ..     ...         ...
# 1995            794          1          0.5         1   0       1           2
# 1996           1965          1          2.6         1   0       0          39
# 1997           1911          0          0.9         1   1       1          36
# 1998           1512          0          0.9         0   4       1          46
# 1999            510          1          2.0         1   5       1          45
#
# ...

# %%
df["dual_sim"].replace({0: "No", 1: "Yes"}, inplace=True)# Dual Sim(change column name and data)

df["four_g"].replace({0: "No", 1: "Yes"}, inplace=True)# 4G(change column name and data)

# %%
df
# Out:
#       battery_power  bluetooth  clock_speed dual_sim  fc four_g  int_memory  \
# 0               842          0          2.2       No   1     No           7
# 1              1021          1          0.5      Yes   0    Yes          53
# 2               563          1          0.5      Yes   2    Yes          41
# 3               615          1          2.5       No   0     No          10
# 4              1821          1          1.2       No  13    Yes          44
# ...             ...        ...          ...      ...  ..    ...         ...
# 1995            794          1          0.5      Yes   0    Yes           2
# 1996           1965          1          2.6      Yes   0     No          39
# 1997           1911          0          0.9      Yes   1    Yes          36
# 1998           1512          0          0.9       No   4    Yes          46
# 1999            510          1          2.0      Yes   5    Yes          45
#
# ...

# %%
df["wifi"].replace({0: "No", 1: "Yes"}, inplace=True)# Wifi column name and data
df["price_range"].replace({0: "Low Cost", 1: "Medium Cost", 2 : "High Cost", 3 : "Very Hight Cost"}, inplace=True)
# Price Range column name and data)

print("Columns and Data Updated Successfully ")
# Out:
# Columns and Data Updated Successfully

# %%
df
# Out:
#       battery_power  bluetooth  clock_speed dual_sim  fc four_g  int_memory  \
# 0               842          0          2.2       No   1     No           7
# 1              1021          1          0.5      Yes   0    Yes          53
# 2               563          1          0.5      Yes   2    Yes          41
# 3               615          1          2.5       No   0     No          10
# 4              1821          1          1.2       No  13    Yes          44
# ...             ...        ...          ...      ...  ..    ...         ...
# 1995            794          1          0.5      Yes   0    Yes           2
# 1996           1965          1          2.6      Yes   0     No          39
# 1997           1911          0          0.9      Yes   1    Yes          36
# 1998           1512          0          0.9       No   4    Yes          46
# 1999            510          1          2.0      Yes   5    Yes          45
#
# ...

# %%
df.head(3)
# Out:
#    battery_power  bluetooth  clock_speed dual_sim  fc four_g  int_memory  \
# 0            842          0          2.2       No   1     No           7
# 1           1021          1          0.5      Yes   0    Yes          53
# 2            563          1          0.5      Yes   2    Yes          41
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# 0         19        0             0   Yes  Medium Cost
# 1          7        1             1    No    High Cost
# 2          9        1             1    No    High Cost
#
# [3 rows x 21 columns]

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x = "px_height", y = "px_width", data=df, hue = "price_range")
# Out:
# <Axes: xlabel='px_height', ylabel='px_width'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = "px_height", y = "px_width", data=df, hue = "price_range").set(title = "Relation of Pixel Height with Price Ranges",
                                                                    xlabel = "Pixel Height"
                                                                   ,ylabel = "Pixel Width")
# Out:
# [Text(0.5, 1.0, 'Relation of Pixel Height with Price Ranges'),
#  Text(0.5, 0, 'Pixel Height'),
#  Text(0, 0.5, 'Pixel Width')]

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x="sc_h",y="sc_w",data=df, hue = "price_range")
# Relation of Screen Height and Screen Width with Price Ranges
# Out:
# <Axes: xlabel='sc_h', ylabel='sc_w'>

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df.corr(), annot = True)
# Out:
# C:\Users\DD\AppData\Local\Temp\ipykernel_10336\3391398152.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <Axes: >

# %%
df.groupby('price_range')['px_height', 'px_width'].mean()
# Out:
# C:\Users\DD\AppData\Local\Temp\ipykernel_10336\3293347090.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('price_range')['px_height', 'px_width'].mean()
#                  px_height  px_width
# price_range
# High Cost          632.284  1234.046
# Low Cost           536.408  1150.270
# Medium Cost        666.892  1251.908
# Very Hight Cost    744.848  1369.838

# %%
df.groupby('ram')['int_memory', 'pc'].mean().head(10)
# Out:
# C:\Users\DD\AppData\Local\Temp\ipykernel_10336\1221497500.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('ram')['int_memory', 'pc'].mean().head(10)
#      int_memory    pc
# ram
# 256        59.0  14.0
# 258        28.0  10.5
# 259        20.0   6.0
# 262        56.0   1.0
# 263        19.0  19.0
# 265        48.0   8.0
# 267        27.0   6.0
# 273        21.0   2.0
# 277        25.0  10.0
# 278        43.5  13.0

# %%
plt.figure(figsize = (7, 5))
sns.distplot(df['battery_power'])
plt.show()
# Out:
# C:\Users\DD\AppData\Local\Temp\ipykernel_10336\3355353234.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['battery_power'])

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(df['ram'], palette = 'icefire')
# Out:
# C:\Users\DD\AppData\Local\Temp\ipykernel_10336\1212288893.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(df['ram'], palette = 'icefire')
# <Axes: ylabel='ram'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.barplot(x=df.index,y=df.values)
# Out:
# <Axes: xlabel='ram'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="ram",y="battery_power",hue="price_range",data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.scatterplot(x="ram",y="battery_power",hue="price_range",data=df)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     745     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...
